# %% [markdown]
# <a href="https://colab.research.google.com/github/MaryaMalyshkina/Grand_line/blob/main/grand_line_detection_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from PIL import Image
from matplotlib.figure import Figure
from pathlib import Path
import random
import shutil
import seaborn as sns, matplotlib.pyplot as plt
import glob, os, yaml, collections
import cv2, glob, os, yaml, matplotlib.pyplot as plt
from google.colab import drive

# %%
# %pip install ultralytics -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 76.9 MB/s eta 0:00:00

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# # Обучение small-модели YOLO на наборе с аугментациями

# %%
model = YOLO("yolo11s.pt")
results = model.train(
    data="/content/drive/MyDrive/defect_detection_2.v3-with_augmentation.yolov11/data.yaml",
    epochs=150,
    patience=30,
    imgsz=640,
    )

metrics = model.val()
print(metrics.box.map)
# Out:
# ...
# Ultralytics 8.4.6 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# Сохранение результатов обучения
source_dir = "/content/runs/detect"
destination_dir = "/content/drive/MyDrive/runs_detect_aug_backup"

# Если папка уже существует, удаляем её
if os.path.exists(destination_dir):
    shutil.rmtree(destination_dir)

# Копируем всю папку с содержимым
shutil.copytree(source_dir, destination_dir)

print(f" Папка успешно скопирована в: {destination_dir}")
# Out:
#  Папка успешно скопирована в: /content/drive/MyDrive/runs_detect_aug_backup

# %% [markdown]
# # Обучение small-модели YOLO на наборе без аугментаций

# %%
model = YOLO("yolo11s.pt")
results = model.train(
    data="/content/drive/MyDrive/defect_detection_2.v4-no_augmentation.yolov11/data.yaml",
    epochs=150,
    patience=30,
    imgsz=640,
    )

metrics = model.val()
print(metrics.box.map)
# Out:
# Ultralytics 8.4.6 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# Сохранение результатов обучения
source_dir = "/content/runs/detect"
destination_dir = "/content/drive/MyDrive/runs_detect_no_aug_backup"

# Если папка уже существует, удаляем её
if os.path.exists(destination_dir):
    shutil.rmtree(destination_dir)

# Копируем всю папку с содержимым
shutil.copytree(source_dir, destination_dir)

print(f" Папка успешно скопирована в: {destination_dir}")
# Out:
#  Папка успешно скопирована в: /content/drive/MyDrive/runs_detect_no_aug_backup
